# %% [markdown]
# **Домашнее задание**
#
# *   Модифицируйте созданную в прошлом домашнем задании программу следующим образом.
# Используйте пакет tensorflow-datasets для загрузки набора данных. Сформируйте pipeline для обучающих и тестовых данных.
# *   Проведите нормализацию данных перед обучением сети. Зафиксируйте начальную (эпоха 1) и конечную (эпоха 10) достигнутые точности без нормализации и с нормализацией.
# *   Измените архитектуру сети следующим образом: используйте один слой на 64 нейрона, либо два слоя на 32 нейрона каждый. Сравните достигнутую точность и время обучения в обоих случаях.
# *   Задайте для оптимизатора параметр learning_rate, равный 10-2, 10-3 или 10-4. Постройте графики роста точности обучения от эпохи к эпохе для всех трёх случаев. Для получения данных используйте объект History, возвращаемый методом .fit().
